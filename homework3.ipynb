# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
class Dice:
    def flip(self):
        return random.randint(1, 6)

# %%
dice = Dice()

# %%
def my_expacted_value(x):
    p = len(x) ** - 1
    summ = 0
    for i in x:
        summ += i * p
    return summ

# %%
def my_mean(x):
    return sum(x)/len(x)

# %%
def my_variance(x):
    return sum([(xi - my_mean(x))**2 for xi in x]) / (len(x) - 1)

# %%
dice_numbers = [i for i in range(1, 7)]
print(my_expacted_value(dice_numbers))
print(my_variance(dice_numbers))
# Out:
# 3.5
# 3.5

# %%
dice_flips = [dice.flip() for i in range(1000000)]
print(my_expacted_value(dice_flips))
print(np.var(dice_flips))
# Out:
# 3.499201999977306
# 2.9162353631960007

# %%
def flip_n(n):
    summ = 0
    for i in range(n):
        summ += dice.flip()
    return summ

# %%
f2 = [flip_n(2) for i in range(200000)]
f4 = [flip_n(4) for i in range(200000)]
f6 = [flip_n(6) for i in range(200000)]
f8 = [flip_n(8) for i in range(200000)]
f10 = [flip_n(10) for i in range(200000)]
f = f2 + f4 + f6 + f8 + f10
plt.hist(f, bins=50)
plt.show()

# %%
f2 = [flip_n(2) for i in range(1000000)]
plt.hist(f2, bins=50)
plt.show()

# %%
f4 = [flip_n(4) for i in range(1000000)]
plt.hist(f4, bins=50)
plt.show()

# %%
f6 = [flip_n(6) for i in range(1000000)]
plt.hist(f6, bins=50)
plt.show()

# %%
f8 = [flip_n(8) for i in range(1000000)]
plt.hist(f8, bins=50)
plt.show()

# %%
f10 = [flip_n(10) for i in range(1000000)]
plt.hist(f10, bins=50)
plt.show()

# %%
print(my_expacted_value(f))
print(np.var(f))
# Out:
# 21.003719999991105
# 115.58312816160004

# %%
def E(n):
    v = [1,2,3,4,5,6]
    r = [i * 1/6 for i in v]
    return n * sum(r)

# %%
def V(n):
    var = 35/12
    return n * var
